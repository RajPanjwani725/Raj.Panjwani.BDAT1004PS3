# %% [markdown]
# # Question 1

# %%
#  Step 1
import pandas as pd

# %%
# Step 2 & 3

users = pd.read_csv('user.txt',sep='|')
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
#  Step 4 Discover what is the mean age per occupation
demo_df=users[['occupation','age']]

demo_df
# Out:
#         occupation  age
# 0       technician   24
# 1            other   53
# 2           writer   23
# 3       technician   24
# 4            other   33
# ..             ...  ...
# 938        student   26
# 939  administrator   32
# 940        student   20
# 941      librarian   48
# 942        student   22
#
# [943 rows x 2 columns]

# %%
demo_df.groupby('occupation').mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %%
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
demo_2_df=users[users['gender']=='M']
demo_2_df=demo_2_df[['occupation','gender']]
demo_2_df
# Out:
#         occupation gender
# 0       technician      M
# 2           writer      M
# 3       technician      M
# 5        executive      M
# 6    administrator      M
# ..             ...    ...
# 935          other      M
# 936       educator      M
# 939  administrator      M
# 940        student      M
# 942        student      M
#
# [670 rows x 2 columns]

# %%
demo_2_df.groupby('occupation').count().sort_values('gender',ascending=False)
# Out:
#                gender
# occupation
# student           136
# other              69
# educator           69
# engineer           65
# programmer         60
# administrator      43
# executive          29
# scientist          28
# technician         26
# writer             26
# librarian          22
# marketing          16
# entertainment      16
# artist             15
# retired            13
# lawyer             10
# salesman            9
# doctor              7
# none                5
# healthcare          5
# homemaker           1

# %%
# Step 6. For each occupation, calculate the minimum and maximum ages

# %%
demo_df.groupby('occupation').max()
# Out:
#                age
# occupation
# administrator   70
# artist          48
# doctor          64
# educator        63
# engineer        70
# entertainment   50
# executive       69
# healthcare      62
# homemaker       50
# lawyer          53
# librarian       69
# marketing       55
# none            55
# other           64
# programmer      63
# retired         73
# salesman        66
# scientist       55
# student         42
# technician      55
# writer          60

# %%
demo_df.groupby('occupation').min()
# Out:
#                age
# occupation
# administrator   21
# artist          19
# doctor          28
# educator        23
# engineer        22
# entertainment   15
# executive       22
# healthcare      22
# homemaker       20
# lawyer          21
# librarian       23
# marketing       24
# none            11
# other           13
# programmer      20
# retired         51
# salesman        18
# scientist       23
# student          7
# technician      21
# writer          18

# %%
# Step 7. For each combination of occupation and sex, calculate the mean age

demo_q1_s7=users[['occupation','gender','age']]
demo_q1_s7.groupby(['occupation','gender']).mean()
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %%
# Step 8. For each occupation present the percentage of women and men

# %%
demo_q1_s7.groupby(['occupation','gender']).sum()
# Out:
#                        age
# occupation    gender
# administrator F       1463
#               M       1598
# artist        F        394
#               M        485
# doctor        M        305
# educator      F       1017
#               M       2974
# engineer      F         59
#               M       2379
# entertainment F         62
#               M        464
# executive     F        132
#               M       1107
# healthcare    F        438
#               M        227
# homemaker     F        205
#               M         23
# lawyer        F         79
#               M        362
# librarian     F       1160
#               M        880
# marketing     F        372
#               M        606
# none          F        146
#               M         93
# other         F       1277
#               M       2348
# programmer    F        193
#               M       1993
# retired       F         70
#               M        813
# salesman      F         81
# ...

# %% [markdown]
# # QUESTION 2

# %%
# Step 1
import pandas as pd

# %%
# Step 2 and 3
euro12=pd.read_csv('Euro_2012_stats_TEAM.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 4. Select only the Goal column
euro12[['Goals']]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %%
# Step 5. How many team participated in the Euro2012?
len(euro12.Team.unique())
# Out:
# 16

# %%
# Step 6. What is the number of columns in the dataset?
euro12.shape[1]
# Out:
# 35

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them
# to a dataframe called discipline
discipline=euro12[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
discipline.sort_values(['Red Cards','Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %%
# Step 9. Calculate the mean Yellow Cards given per Team

discipline[['Team','Yellow Cards']].groupby('Team').mean()
# Out:
#                      Yellow Cards
# Team
# Croatia                       9.0
# Czech Republic                7.0
# Denmark                       4.0
# England                       5.0
# France                        6.0
# Germany                       4.0
# Greece                        9.0
# Italy                        16.0
# Netherlands                   5.0
# Poland                        7.0
# Portugal                     12.0
# Republic of Ireland           6.0
# Russia                        6.0
# Spain                        11.0
# Sweden                        7.0
# Ukraine                       5.0

# %%
# Step 10
data_goals=euro12[euro12['Goals']>6]
data_goals
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Step 11.

euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# Step 12.
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 13.
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 14.
euro12_teams=euro12[euro12['Team'].isin(['England','Italy','Russia'])]
euro12_teams
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 3   England      5               11                18             50.0%
# 7     Italy      6               34                45             43.0%
# 12   Russia      5                9                31             22.5%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 3             17.2%                          40             0              0
# 7              7.5%                         110             2              0
# 12            12.5%                          59             2              0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 3                      0  ...          22                 88.1%         43
# 7                      0  ...          20                 74.1%        101
# 12                     0  ...          10                 77.0%         34
#
# ...

# %%
euro12_teams[['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3

# %%
# Step 1
import random
import pandas as pd

# %%
# Step 2
series_1=[]
for i in range(0,100):
    series_1.append(random.randint(1,4))

# %%
series_1=pd.Series(series_1)
series_1
# Out:
# 0     3
# 1     4
# 2     4
# 3     2
# 4     4
#      ..
# 95    3
# 96    4
# 97    2
# 98    2
# 99    2
# Length: 100, dtype: int64

# %%
series_2=[]
for i in range(0,100):
    series_2.append(random.randint(1,3))

# %%
series_2=pd.Series(series_2)
series_2
# Out:
# 0     1
# 1     2
# 2     1
# 3     1
# 4     2
#      ..
# 95    1
# 96    1
# 97    3
# 98    2
# 99    3
# Length: 100, dtype: int64

# %%
series_3=[]
for i in range(0,100):
    series_3.append(random.randint(10000,30000))

# %%
series_3=pd.Series(series_3)
series_3
# Out:
# 0     19989
# 1     29009
# 2     24333
# 3     22492
# 4     12323
#       ...
# 95    19817
# 96    27004
# 97    20303
# 98    26924
# 99    10750
# Length: 100, dtype: int64

# %%
# Step 3 Create a dataframe by joining series by columns
series=pd.concat([series_1,series_2,series_3],axis=1)
series
# Out:
#     0  1      2
# 0   3  1  19989
# 1   4  2  29009
# 2   4  1  24333
# 3   2  1  22492
# 4   4  2  12323
# .. .. ..    ...
# 95  3  1  19817
# 96  4  1  27004
# 97  2  3  20303
# 98  2  2  26924
# 99  2  3  10750
#
# [100 rows x 3 columns]

# %%
# Step 4
series.rename(columns={0:'bedrs',1:'bathrs',2:'price_sqr_meter'},inplace=True)

# %%
series
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       1            19989
# 1       4       2            29009
# 2       4       1            24333
# 3       2       1            22492
# 4       4       2            12323
# ..    ...     ...              ...
# 95      3       1            19817
# 96      4       1            27004
# 97      2       3            20303
# 98      2       2            26924
# 99      2       3            10750
#
# [100 rows x 3 columns]

# %%
#  STEP 5
bigcolumn=pd.concat([series_1,series_2,series_3])
bigcolumn
# Out:
# 0         3
# 1         4
# 2         4
# 3         2
# 4         4
#       ...
# 95    19817
# 96    27004
# 97    20303
# 98    26924
# 99    10750
# Length: 300, dtype: int64

# %%
# Step 6
bigcolumn.shape,bigcolumn.index[-1]==99
# Out:
# ((300,), True)

# %% [markdown]
# - It seems that index is going till 99 but its not true because one series is below another

# %%
# Step 7
bigcolumn.reset_index(drop=True,inplace=True)
bigcolumn
# Out:
# 0          3
# 1          4
# 2          4
# 3          2
# 4          4
#        ...
# 295    19817
# 296    27004
# 297    20303
# 298    26924
# 299    10750
# Length: 300, dtype: int64

# %% [markdown]
# # Question 4

# %%
# Step 1,2 and 3
import pandas as pd
import datetime
wind_data=pd.read_csv('Wind Statistics.txt',sep='\s+')

# %%
type(wind_data)
# Out:
# pandas.core.frame.DataFrame

# %%
wind_data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
#     Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index.

# %%
year=[]
for i in wind_data['Yr']:
#     print(i)
    yr='19'+str(i)
    year.append(int(yr))

# %%
year
# Out:
# [1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
#  1961,
# ...

# %%
wind_data['Yr']=year

# %%
wind_data
# Out:
#         Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...    ...  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
wind_data['Yr_Mo_Dy']=wind_data['Yr'].astype(str)+"-"+wind_data['Mo'].astype(str)+"-"+wind_data['Dy'].astype(str)
wind_data
# Out:
#         Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...    ...  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL    Yr_Mo_Dy
# ...

# %%
wind_data.drop(['Yr','Mo','Dy'],axis=1,inplace=True)

# %%
wind_data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL    Yr_Mo_Dy
# 0     18.50  15.04    1961-1-1
# ...

# %%
wind_data['Yr_Mo_Dy']=pd.to_datetime(wind_data['Yr_Mo_Dy'])
wind_data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL   Yr_Mo_Dy
# 0     18.50  15.04 1961-01-01
# ...

# %% [markdown]
# - Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it
#
# - Answer : We dont have the data of year 2061 as the year didnt came

# %%
# Step 5
wind_data.set_index(wind_data['Yr_Mo_Dy'],inplace=True)
wind_data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL   Yr_Mo_Dy
# Yr_Mo_Dy
# ...

# %%
# Step 6
wind_data.isnull().sum()
# Out:
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# Yr_Mo_Dy    0
# dtype: int64

# %%
wind_data=wind_data.dropna()
wind_data
# Out:
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-04  10.58   6.63  11.75  4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42  6.17  10.71   8.21  11.92   6.54  10.92
# 1961-01-06  13.21   8.12   9.96  6.67   5.37   4.50  10.67   4.42   7.17
# 1961-01-07  13.50  14.29   9.50  4.96  12.29   8.33   9.17   9.29   7.58
# 1961-01-08  10.96   9.75   7.62  5.91   9.62   7.29  14.29   7.62   9.25
# ...           ...    ...    ...   ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62  8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46  5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42  8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29  9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29  9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL   Yr_Mo_Dy
# Yr_Mo_Dy
# ...

# %%
# Step 7. Compute how many non-missing values there are in total.
wind_data.notnull().sum()
# Out:
# RPT         6546
# VAL         6546
# ROS         6546
# KIL         6546
# SHA         6546
# BIR         6546
# DUB         6546
# CLA         6546
# MUL         6546
# CLO         6546
# BEL         6546
# MAL         6546
# Yr_Mo_Dy    6546
# dtype: int64

# %%
wind_data.notnull().sum().sum()
# Out:
# 85098

# %%
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times.

# %%
wind_data.mean()
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# RPT    12.359979
# VAL    10.640267
# ROS    11.656396
# KIL     6.298587
# SHA    10.448923
# BIR     7.085066
# DUB     9.793006
# CLA     8.486601
# MUL     8.490257
# CLO     8.696705
# BEL    13.110668
# MAL    15.603129
# dtype: float64

# %%
wind_data.mean().mean()
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# 10.222465245951726

# %%
# Step 9.
loc_stats=wind_data.describe()

# %%
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean     12.359979    10.640267    11.656396     6.298587    10.448923
# std       5.618805     5.268695     5.007805     3.600942     4.933988
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     7.970000     3.580000     6.750000
# 50%      11.710000    10.130000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.380000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean      7.085066     9.793006     8.486601     8.490257     8.696705
# std       3.967735     4.978030     4.498299     4.165947     4.500488
# ...

# %%
# Step 10.
day_stats = pd.DataFrame()

# %%
day_stats['min'] = wind_data.min(axis = 1) 
day_stats['max'] = wind_data.max(axis = 1) 
day_stats['mean'] = wind_data.mean(axis = 1) 
day_stats['std'] = wind_data.std(axis = 1)
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
# ...

# %%
day_stats
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# 1961-01-06  4.42  13.21   8.240000  2.998063
# 1961-01-07  4.96  14.29  10.385000  3.072114
# 1961-01-08  5.91  16.62  10.487500  3.547237
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6546 rows x 4 columns]

# %%
# Step 11
temp_wind_data =wind_data[(wind_data.index.year==1962) | (wind_data.index.year==196)]
temp_wind_data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1962-01-01   9.29   3.42  11.54   3.50   2.21   1.96  10.41   2.79   3.54
# 1962-01-02   6.08   3.13   5.09   0.87   0.42   0.33   8.46   0.00   0.54
# 1962-01-03   7.75   4.46   6.04   3.17   3.58   0.42   4.58   0.00   3.08
# 1962-01-04   3.17   4.92   4.38   1.04   3.50   1.79   5.50   3.75   1.63
# 1962-01-05  11.67  13.04  11.38   4.79  11.42   8.96  15.29  10.75   9.13
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1962-12-27  13.62  12.96  19.83   8.42   5.66   4.92  11.92   7.21   6.58
# 1962-12-28  12.67  10.71  17.75   6.83   7.75   4.42   7.79   4.92   5.71
# 1962-12-29  19.29  13.13  22.79   7.17  11.00   6.54  13.62   8.00   7.21
# 1962-12-30  22.00  19.70  33.84  19.83  20.08  18.46  28.79  21.59  18.75
# 1962-12-31  22.67  16.88  28.67  14.12  19.75  17.08  27.79  25.21  19.83
#
#               CLO    BEL    MAL   Yr_Mo_Dy
# Yr_Mo_Dy
# ...

# %%
temp_wind_data.loc[temp_wind_data.index.month==1].mean()
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# RPT    14.783871
# VAL    13.160323
# ROS    12.591935
# KIL     7.538065
# SHA    11.779677
# BIR     8.720000
# DUB    14.211935
# CLA     9.600000
# MUL     9.670000
# CLO    11.498710
# BEL    16.369355
# MAL    15.661613
# dtype: float64

# %% [markdown]
# # Question 5

# %%
# Step 1.

import pandas as pd

# %%
# Step 2 and Step 3
chipo=pd.read_table('chipotle.txt')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 4 
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5

# %%
print("Number of observation in the data are  : ",chipo.shape[0])
# Out:
# Number of observation in the data are  :  4622

# %%
# Step 6
print("Number of columns in the data are  : ",chipo.shape[1])
# Out:
# Number of columns in the data are  :  5

# %%
# Step 7
print("Name of all columns in the data are  : ",chipo.columns)
# Out:
# Name of all columns in the data are  :  Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ###  Step 8
# - the index of data is [0,1,2,3.....4622]

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Step 9. Which was the most-ordered item?

# %%
chipo['item_name'].mode()[0]
# Out:
# 'Chicken Bowl'

# %%
# Step 10.
chipo[chipo['item_name']==chipo['item_name'].mode()[0]].count()
# Out:
# order_id              726
# quantity              726
# item_name             726
# choice_description    726
# item_price            726
# dtype: int64

# %%
# Step 11. What was the most ordered item in the choice_description column?

# %%
chipo['choice_description'].mode()[0]
# Out:
# '[Diet Coke]'

# %%
#  Step 12
chipo[chipo['choice_description']==chipo['choice_description'].mode()[0]].count()
# Out:
# order_id              134
# quantity              134
# item_name             134
# choice_description    134
# item_price            134
# dtype: int64

# %%
# Step 13(a)
item_price_demo=[]
for i in chipo['item_price'].iloc[:]:
#     print(i)
    j=i.split('$')
#     print(j)
    item_price_demo.append(float(j[1]))
item_price_demo
# Out:
# [2.39,
#  3.39,
#  3.39,
#  2.39,
#  16.98,
#  10.98,
#  1.69,
#  11.75,
#  9.25,
#  9.25,
#  4.45,
#  8.75,
#  8.75,
#  11.25,
#  4.45,
#  2.39,
#  8.49,
#  8.49,
#  2.18,
#  8.75,
#  4.45,
#  8.99,
#  3.39,
#  10.98,
#  3.39,
#  2.39,
#  8.49,
#  8.99,
#  1.09,
#  8.49,
#  2.39,
#  8.99,
#  1.69,
#  8.99,
#  1.09,
#  8.75,
#  8.75,
#  4.45,
#  2.95,
#  11.75,
#  2.15,
#  4.45,
#  11.25,
#  11.75,
#  8.75,
#  10.98,
#  8.99,
#  3.39,
#  8.99,
#  3.99,
#  8.99,
#  2.18,
#  10.98,
#  1.09,
#  8.99,
#  2.39,
#  9.25,
#  11.25,
#  11.75,
#  2.15,
#  4.45,
#  9.25,
#  11.25,
#  8.75,
#  8.99,
#  8.99,
#  3.39,
#  8.99,
#  10.98,
#  8.99,
#  1.69,
#  8.99,
#  3.99,
#  8.75,
#  4.45,
#  8.75,
#  8.75,
#  2.15,
#  8.75,
#  11.25,
#  2.15,
#  9.25,
#  8.75,
#  8.75,
#  9.25,
#  8.49,
#  8.99,
#  1.09,
#  9.25,
#  2.95,
#  11.75,
#  11.75,
#  9.25,
#  11.75,
#  4.45,
#  9.25,
#  4.45,
#  11.75,
#  8.75,
#  8.75,
#  4.45,
#  8.99,
#  8.99,
#  3.99,
#  8.49,
#  3.39,
#  8.99,
#  1.09,
#  9.25,
# ...

# %%
chipo['item_price']=item_price_demo

# %%
chipo['item_price']=chipo['item_price'].astype('float')

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# Step 13(b)
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %% [markdown]
# # 13(c )

# %%
# c= lambda i : for i in chipo['item_price'].iloc[0:]

# %%
# Step 14
chipo['item_price'].sum().sum()
# Out:
# 34500.16

# %%
# Step 15
chipo.shape[0]
# Out:
# 4622

# %%
# Step 16
chipo['item_price'].mean()
# Out:
# 7.464335785374297

# %%
# Step 17
len(chipo['item_name'].unique())
# Out:
# 50

# %% [markdown]
# # Question 6

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
marriage_data = pd.read_csv("us-marriages-divorces-1867-2014.csv")

# %%
marriage_data_range=marriage_data[(marriage_data['Year']>1867) & (marriage_data['Year']<2014) ]

# %%
marriage_data_range
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# 5    1872   378000.0   12000.0    42066000                 9.0
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# 5                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
data_marriage_work=marriage_data_range[['Year','Marriages']]
data_marriage_work.set_index('Year',inplace=True)
data_marriage_work
# Out:
#       Marriages
# Year
# 1868   345000.0
# 1869   348000.0
# 1870   352000.0
# 1871   359000.0
# 1872   378000.0
# ...         ...
# 2007  2197000.0
# 2008  2157000.0
# 2009  2080000.0
# 2010  2096000.0
# 2011  2118000.0
#
# [144 rows x 1 columns]

# %%
data_marriage_divorced=marriage_data_range[['Year','Divorces']]
data_marriage_divorced.set_index('Year',inplace=True)
data_marriage_divorced
# Out:
#       Divorces
# Year
# 1868   10000.0
# 1869   11000.0
# 1870   11000.0
# 1871   12000.0
# 1872   12000.0
# ...        ...
# 2007  856000.0
# 2008  844000.0
# 2009  840000.0
# 2010  872000.0
# 2011  877000.0
#
# [144 rows x 1 columns]

# %%
data_main=pd.concat([data_marriage_work,data_marriage_divorced],axis=1)
data_main.reset_index(inplace=True)
data_main
# Out:
#      Year  Marriages  Divorces
# 0    1868   345000.0   10000.0
# 1    1869   348000.0   11000.0
# 2    1870   352000.0   11000.0
# 3    1871   359000.0   12000.0
# 4    1872   378000.0   12000.0
# ..    ...        ...       ...
# 139  2007  2197000.0  856000.0
# 140  2008  2157000.0  844000.0
# 141  2009  2080000.0  840000.0
# 142  2010  2096000.0  872000.0
# 143  2011  2118000.0  877000.0
#
# [144 rows x 3 columns]

# %%
plt.plot('Year','Marriages',data=data_main)
plt.plot('Year','Divorces',data=data_main)
plt.title("Marriage and Divorces per Year")
plt.ylabel("Count of Marriage and Divorce")
plt.xlabel("Year")
plt.legend()
plt.show()

# %% [markdown]
# # Question 7

# %%
marriage_data_range=marriage_data[(marriage_data['Year']==1900) | (marriage_data['Year']==1950) | (marriage_data['Year']==2000) ]

# %%
marriage_data_range
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 33   1900   709000.0   56000.0    76094000                 9.3
# 83   1950  1667000.0  385000.0   151684000                11.0
# 133  2000  2315000.0  944000.0   282398000                 8.2
#
#      Divorces_per_1000
# 33                 0.7
# 83                 2.5
# 133                3.3

# %%
marriage_data_range.plot(x='Year',y=['Marriages','Divorces'],kind='bar')
plt.ylabel("Count of  Marriage and Divorce")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # Question 8

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data_kill=pd.read_csv('actor_kill_counts.csv')
data_kill
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
sns.barplot('Count','Actor',data=data_kill)
plt.ylabel("actor")
plt.xlabel("count")
plt.show()
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Question 9

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data_emperor=pd.read_csv('roman-emperor-reigns.csv')
data_emperor
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
data_Assassinated=data_emperor[data_emperor['Cause_of_Death']=='Assassinated']
data_Assassinated
# Out:
#                Emperor  Length_of_Reign Cause_of_Death
# 2             Caligula             4.83   Assassinated
# 5                Galba             0.58   Assassinated
# 7            Vitellius             0.67   Assassinated
# 10            Domitian            15.00   Assassinated
# 17            Commodus            15.00   Assassinated
# 18            Pertinax             0.25   Assassinated
# 21           Caracalla            19.00   Assassinated
# 22                Geta             3.00   Assassinated
# 24          Elagabalus             3.75   Assassinated
# 25   Severus Alexander            13.00   Assassinated
# 26         Maximinus I             3.25   Assassinated
# 29            Pupienus             0.25   Assassinated
# 30            Balbinus             0.25   Assassinated
# 35  Trebonianus Gallus             2.00   Assassinated
# 36            Aemilian             0.16   Assassinated
# 38           Gallienus            15.00   Assassinated
# ...

# %%
plt.pie(data_Assassinated['Length_of_Reign'],labels=data_Assassinated['Emperor'],radius=3,autopct='%1.f%%')

plt.show()

# %% [markdown]
# # Question 10

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data_revenue=pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
data_revenue
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
data_revenue_year=data_revenue[(data_revenue['Year']>2000) & ( data_revenue['Year']<2009)]
data_revenue_year
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
#
#    Computer Science Doctorates Awarded (US)
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787

# %%
plt.scatter('Total Arcade Revenue (billions)','Computer Science Doctorates Awarded (US)',data=data_revenue_year)
# plt.scatter('Year','Computer Science Doctorates Awarded (US)',data=data_revenue_year)

# %%
sns.scatterplot('Total Arcade Revenue (billions)','Computer Science Doctorates Awarded (US)',data=data_revenue_year,hue='Year')
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Total Arcade Revenue (billions)', ylabel='Computer Science Doctorates Awarded (US)'>
